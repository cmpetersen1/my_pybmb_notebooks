# %% [markdown]
# <a href="https://colab.research.google.com/github/cmpetersen1/my_pybmb_notebooks/blob/main/test_notebook_PyBMB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
